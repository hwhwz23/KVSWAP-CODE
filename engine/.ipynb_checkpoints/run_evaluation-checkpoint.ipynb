# %% [markdown]
# XXXX

# %% [markdown]
# ## Table 4

# %% [markdown]
# export EMMC_DEV_NAME=mmcblk0
# export EMMC_OFFLOAD_DIR=
# export NVME_DEV_NAME=nvme0n1
# export NVME_OFFLOAD_DIR=
#
#
# export MODEL_PATH_BASE_HF=./data/model_weights_hf
# export MODEL_PATH_BASE=./data/model_weights_np

# %%
! bash ./scripts/tab-4.sh

# %% [markdown]
# ## Figure 10

# %%
! bash ./scripts/fig-10.sh

# %% [markdown]
# ## Figure 11 (throughput)

# %%
! bash ./scripts/fig-11-tp.sh
